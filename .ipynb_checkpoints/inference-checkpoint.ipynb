# %%
import torch.serialization
import _codecs
import numpy as np

torch.serialization.add_safe_globals([np.core.multiarray.scalar, np.dtype, np.dtypes.Float64DType, _codecs.encode])

# %%
import nnunet
print(nnunet.__file__)
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# C:\Users\ajhz839\develop\anaconda\envs\unet\lib\site-packages\nnunet\__init__.py

# %%
import os
os.environ["nnUNet_raw_data_base"] = r"C:\Users\ajhz839\nnunet_workdir\nnUNet_raw_data_base"
os.environ["nnUNet_preprocessed"] = r"C:\Users\ajhz839\nnunet_workdir\nnUNet_preprocessed"
os.environ["RESULTS_FOLDER"] = r"C:\Users\ajhz839\nnunet_workdir\nnUNet_trained_models"

# %%
# !nnUNet_predict -i C:/Users/ajhz839/nnunet_workdir/nnUNet_raw_data_base/Task001_BrainTumour/imagesTs/ -o C:/Users/ajhz839/nnunet_data/results/brain_tumour_predictions -t 1 --save_npz -m 3d_fullres
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
#
#
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  C:\Users\ajhz839\nnunet_workdir\nnUNet_trained_models\nnUNet\3d_fullres\Task001_BrainTumour\nnUNetTrainerV2__nnUNetPlansv2.1
# This model expects 4 input modalities for each image
# ...

# %% [markdown]
# ## nnUNetv2

# %%
import os
os.environ["nnUNet_raw"] = r"C:\Users\ajhz839\nnunet_data\nnUNet_raw"
os.environ["nnUNet_preprocessed"] = r"C:\Users\ajhz839\nnunet_data\nnUNet_preprocessed"
os.environ["nnUNet_results"] = r"C:\Users\ajhz839\nnunet_data\nnUNet_results"

# %%
# !nnUNetv2_predict -i C:\Users\ajhz839\nnunet_data\nnUNet_raw\Task001_BrainTumour\imagesTs\ -o C:\Users\ajhz839\nnunet_data\results\brain_tumour_predictions -t 1 -d 1 -c nnUNetPlansv2.1 --verbose
# Out:
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
# Traceback (most recent call last):
#   File "C:\Users\ajhz839\develop\anaconda\envs\jelly\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\ajhz839\develop\anaconda\envs\jelly\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\ajhz839\develop\anaconda\envs\jelly\Scripts\nnUNetv2_predict.exe\__main__.py", line 7, in <module>
#   File "C:\Users\ajhz839\develop\anaconda\envs\jelly\lib\site-packages\nnunetv2\inference\predict_from_raw_data.py", line 951, in predict_entry_point
# ...
